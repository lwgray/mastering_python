# %% [markdown]
# # In-place Addition and Subtraction

# %% [markdown]
# ##**In-place Addition (+=):**

# %%
x = 5
x += 3 # Equivalent to x = x + 3
print(x)
# Out:
# 8

# %% [markdown]
# ##**In-place Subtraction (-=):**

# %%
y = 10
y -= 4 # Equivalent to y = y - 4
print(y)
# Out:
# 6
