# %%
print("hello")
print("goodbye!"

# %% [markdown]
# When an error occurs in your code, Python provides a traceback, a detailed report of the functions called at the point where the error occurred. While the traceback output may seem intimidating at first, it contains valuable information to help you diagnose and fix the issue. Understanding the traceback is a crucial step in growing as a Python programmer.
#
# ## Understanding a Traceback
# <p><font color='teal'>File</font> <font color='green'>path</font><font color='teal'>, line </font><font color='green'> number</font></p>
# <p>&nbsp;&nbsp;&nbsp;&nbsp;<font color='maroon'>line that caused the error</font></p>
# <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<font color="teal">^ indicator of the error location</font></p>
#
# <p><font color='maroon'>error type: </font><font color='teal'>error message</font></p>
#
# By understanding these elements, you are well on your way to becoming proficient in Python programming. Happy coding!
