# %% [markdown]
# ### Assignment: Understanding Python Data Types
# **Instructions:**
# Understanding the basics of data types is crucial for programming in Python. In this coding assignment, you will practice using the different data types in Python and get familiar with their properties.
#
# 1. Define the following variables with the correct data types:
#  * A string called “name” and assign it your full name as a string value.
#  * An integer called “age” and assign it your current age as an integer value.
#  * A float called “height” and assign it your height in meters as a float value.
#  * A boolean called “is_student” and assign it True or False depending on whether you are a student or not.
# 2. Print out each of the variables you created in step 3 to make sure they have the correct values.
#
# 3. Create a list called “favorites” and assign it the following values: your favorite color, favorite food, and favorite movie as strings.
#
# 4. Use the “len” function to find the length of the “favorites” list.
#
# 5. Create a dictionary called “personal_info” and assign the following key-value pairs:
#         a. “name”: your full name as a string
#         b. “age”: your age as an integer
#         c. “height”: your height in meters as a float
#         d. “is_student”: True or False depending on whether you are a student or not.
# 6. Use the “keys” method to find the keys in the “personal_info” dictionary.
#
# 7. Use the “values” methods to find the values in the “personal_info” dictionary.

# %%
name = "Larry Gray"
age = 43
height = 1.8
is_student = False

print(name, age, height, is_student)

favorites = ['blue', 'pho', 'blue streak']

len_favorites = len(favorites)

personal_info = {"name":name, "age": age, "height": height,
                 "is_student": is_student}

keys = personal_info.keys()
values = personal_info.values()
