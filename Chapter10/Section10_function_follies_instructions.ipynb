# %% [markdown]
# # Function Follies with Professor Python 🐍
#
# ## How to Complete These Exercises
# Hello there, future Pythonistas! It's time to play around with functions in Python. Professor Python has cooked up some really fun exercises for you to flex those coding muscles. So, put on your coding hats and get ready to write some Python functions!
#
# ### Instructions:
# 1. For each exercise, write a function that performs the given task.
# 2. Test your function with some example inputs to ensure it's working as expected.
# 3. Comment your code to explain the logic behind your solution.
#
# Ready? Let's get started!
#
# ---
#
# ### Exercise 1: Piggy Bank 🐷
# Create a function to calculate the total amount in your piggy bank! Your function should:
# - Accept four arguments: the number of pennies, nickels, dimes, and quarters you have.
# - Calculate the total amount you've got stashed away in dollars and cents.
# - Return the total amount in dollars as a float.
#
# **Example:**
# ```python
# print(piggy_bank(10, 5, 2, 3))  # Should return 1.05
# ```
#
# ---
#
# ### Exercise 2: Movie Night 🍿
# Movie nights just got a whole lot easier! Write a function to help you pick the perfect film. Your function should:
# - Accept a list of movies, where each movie is a dictionary with a 'title' and a 'genre'.
# - Take a second argument for the genre you're in the mood for.
# - Filter out and return a list of movies that match your chosen genre.
#
# **Example:**
# ```python
# movies = [{'title': 'Inception', 'genre': 'Action'}, {'title': 'Shrek', 'genre': 'Animation'}]
# print(movie_night(movies, 'Action'))  # Should return [{'title': 'Inception', 'genre': 'Action'}]
# ```
#
# ---
#
# ### Exercise 3: Weather Forecast ☀️☔
# Ever stepped out in shorts on a freezing day? Let's make sure that never happens again! Create a function to suggest what to wear based on the weather. Your function should:
# - Accept the current temperature and the weather condition (e.g., "sunny", "rainy").
# - Give you a string recommendation on what to wear for the day.
#
# **Example:**
# ```python
# print(weather_forecast(75, 'sunny'))  # Should return 'Wear a t-shirt and sunglasses!'
# ```
#
# Good luck and have fun coding! 🎉
