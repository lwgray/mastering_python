# %% [markdown]
# **Game Outline**: **"Space Race"**
#
# In "Space Race", two players each choose a spaceship. Each spaceship has a speed. The player with the faster spaceship wins the round. The game continues for 3 rounds, and the player with the most round wins at the end is declared the winner.
#
# **Code with Fill-in-the-blanks**:
#
# ```python
# ```
#
# Here, the functions `get_round_winner` and `play_round` were left blank, with `get_round_winner` being the medium difficulty function to fill in and `play_round` being the easier one. The spaceship speeds in the `spaceships` dictionary were also left as fill-in-the-blanks.

# %%
# Define the spaceships and their speeds
spaceships = {
    "Rocket": ___1___,
    "Shuttle": ___2___,
    "UFO": ___3___,
    "Starship": ___4___
}

def get_round_winner(player1_choice, player2_choice):
    """
    Determine the winner of a round based on spaceship speeds.

    Parameters
    ----------
    player1_choice : str
        The spaceship chosen by Player 1.
    player2_choice : str
        The spaceship chosen by Player 2.

    Returns
    -------
    str
        "Player 1" if Player 1's spaceship is faster, "Player 2" if Player 2's spaceship is faster,
        and "Draw" if both spaceships have the same speed.
    """
    ___5___
    # Fill in the logic to determine the round winner

def get_game_winner(player1_wins, player2_wins):
    """
    Determine the overall game winner based on the number of round wins.

    Parameters
    ----------
    player1_wins : int
        Number of rounds won by Player 1.
    player2_wins : int
        Number of rounds won by Player 2.

    Returns
    -------
    str
        "Player 1" if Player 1 won more rounds, "Player 2" if Player 2 won more rounds,
        and "Draw" if both players won the same number of rounds.
    """
    if player1_wins > player2_wins:
        return "Player 1"
    elif player1_wins < player2_wins:
        return "Player 2"
    else:
        return "Draw"

def play_round():
    """
    Execute a round where both players choose a spaceship and the round winner is determined.

    Returns
    -------
    str
        Winner of the round ("Player 1", "Player 2", or "Draw").
    """
    player1_choice = input("Player 1, choose your spaceship: ")
    player2_choice = input("Player 2, choose your spaceship: ")

    return ___6___  # Fill in the appropriate function to determine the round winner

def play_game():
    """
    Execute the main game logic for 3 rounds and determine the overall game winner.

    Returns
    -------
    None
    """
    player1_score = 0
    player2_score = 0

    for _ in range(3):
        winner = play_round()

        if winner == "Player 1":
            player1_score += 1
        elif winner == "Player 2":
            player2_score += 1

    game_winner = get_game_winner(player1_score, player2_score)
    print(f"The winner of Space Race is: {game_winner}")

play_game()
