# %% [markdown]
# # Mystery on Elm Street

# %% [markdown]
# Welcome to "Mystery on Elm Street," a text-based detective game where you are called to solve a mystery in a small town.
# You'll have to gather clues, interrogate suspects, and finally make an accusation to solve the case.

# %% [markdown]
# ## Backstory
#
# You are Detective Alex, and you've been called to Elm Street, a small town where a mysterious event has occurred.
# The town is in a state of panic, and it's up to you to solve the mystery and bring peace back to Elm Street.
#
# Time to unravel the mystery!

# %% [markdown]
# ### Fill-in-the-Blank Instructions with Hints
#
# 1. **choose_location():** Implement the logic to let the player choose a location to visit for clues.
#
# 2. **gather_clues(location):** Implement the logic for gathering clues at the chosen location.
#
# 3. **interrogate_suspects():** Implement the logic for interrogating suspects.
#
# 4. **make_accusation():** Implement the logic to allow the player to make an accusation and solve the mystery.

# %%
def choose_location():
    """
    This function allows the player to choose a location to visit for gathering clues.

    Returns:
        str: The location chosen by the player.
    """
    # Extended Hint: Initialize a list to store location options.
    # Use the enumerate() function in a for loop to display each option with a number.
    # Example: for index, option in enumerate(options)
    # Capture the user's input with input() and convert it to an integer.
    # Use this integer to fetch the selected location from the list.
    ___1___

def gather_clues(location):
    """
    This function gathers clues based on the location chosen by the player.

    Parameters:
        location (str): The location where the player wants to gather clues.

    Returns:
        list: A list of clues gathered.
    """
    # Extended Hint: Initialize a dictionary with locations as keys and clues as values.
    # Example: {'Library': ['clue1', 'clue2'], 'Cafe': ['clue3', 'clue4']}
    # Use the chosen location as a key to fetch the relevant clues from the dictionary.
    ___2___

def interrogate_suspects():
    """
    This function allows the player to interrogate suspects to gather more information.

    Returns:
        list: A list of statements from the suspects.
    """
    # Extended Hint: Create two lists, one for suspect names and another for their statements.
    # Display the suspects using enumerate() in a for loop.
    # Example: for index, suspect in enumerate(suspects)
    # Capture the user's choice with input() and use it to fetch the corresponding statement.
    ___3___

def make_accusation():
    """
    This function allows the player to make an accusation to solve the mystery.

    Returns:
        bool: True if the accusation is correct, False otherwise.
    """
    # Extended Hint: Use input() to capture the player's accusation.
    # Store the correct answer in a variable.
    # Use an if statement to compare the player's accusation to the correct answer.
    ___4___

def main():
    """
    The main function where the game loop resides.
    """
    while True:
        location = choose_location()
        clues = gather_clues(location)
        print(f"Clues gathered at {location}: {clues}")

        statement = interrogate_suspects()
        print(f"Suspect says: {statement}")

        accusation = make_accusation()
        if accusation:
            print("Congratulations, you solved the mystery!")
            break
        else:
            print("Wrong accusation. Keep investigating.")

main()
